# %%
import requests
adres = "Hoogstraat 146, 9160 Lokeren"
response = requests.get(f"https://loc.geopunt.be/v4/location?q={adres}").json()
response
# Out:
# {'LocationResult': [{'Municipality': 'Lokeren',
#    'Zipcode': '9160',
#    'Thoroughfarename': 'Hoogstraat',
#    'Housenumber': '146',
#    'ID': 1126242,
#    'FormattedAddress': 'Hoogstraat 146, 9160 Lokeren',
#    'Location': {'Lat_WGS84': 51.10529617014935,
#     'Lon_WGS84': 3.961153456170891,
#     'X_Lambert72': 121452.31,
#     'Y_Lambert72': 199545.21},
#    'LocationType': 'crab_huisnummer_manueleAanduidingVanIngangVanGebouw',
#    'BoundingBox': {'LowerLeft': {'Lat_WGS84': 51.10529617014935,
#      'Lon_WGS84': 3.961153456170891,
#      'X_Lambert72': 121452.31,
#      'Y_Lambert72': 199545.21},
#     'UpperRight': {'Lat_WGS84': 51.10529617014935,
#      'Lon_WGS84': 3.961153456170891,
#      'X_Lambert72': 121452.31,
#      'Y_Lambert72': 199545.21}}}]}

# %%
import requests
import earthpy.plot as ep
import json
streetname = input('Give me the streetname?')
housenumber = input('Give me the housenumber?')
zipcode = input('Give me the zipcode?')
adres_api = {"straatnaam":{streetname}, "huisnummer":{housenumber}, "postcode":{zipcode}}
api_url = "https://api.basisregisters.vlaanderen.be/v1/adresmatch"
response3 = requests.get(url = api_url, params = adres_api).json()
response3
# Out:
# /Users/Jorg/opt/anaconda3/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# {'adresMatches': [{'identificator': {'id': 'https://data.vlaanderen.be/id/adres/1410900',
#     'naamruimte': 'https://data.vlaanderen.be/id/adres',
#     'objectId': '1410900',
#     'versieId': '2013-03-29T06:33:22+01:00'},
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/adressen/1410900',
#    'gemeente': {'objectId': '11002',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/gemeenten/11002',
#     'gemeentenaam': {'geografischeNaam': {'spelling': 'Antwerpen',
#       'taal': 'nl'}}},
#    'postinfo': {'objectId': '2000',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/postinfo/2000'},
#    'straatnaam': {'objectId': '2655',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/straatnamen/2655',
#     'straatnaam': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet',
#       'taal': 'nl'}}},
#    'huisnummer': '7',
#    'volledigAdres': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet 7, 2000 Antwerpen',
#      'taal': 'nl'}},
#    'adresPositie': {'point': {'coordinates': [152242.43, 212849.5],
#      'type': 'Point'}},
#    'positieSpecificatie': 'gebouweenheid',
#    'positieGeometrieMethode': 'afgeleidVanObject',
#    'adresStatus': 'inGebruik',
#    'officieelToegekend': True,
#    'adresseerbareObjecten': [{'objectType': 'gebouweenheid',
#      'objectId': '16689264',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/16689264'},
#     {'objectType': 'perceel',
#      'objectId': '11002A1949-03A000',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/percelen/11002A1949-03A000'}],
#    'score': 100.0},
#   {'identificator': {'id': 'https://data.vlaanderen.be/id/adres/4334803',
#     'naamruimte': 'https://data.vlaanderen.be/id/adres',
#     'objectId': '4334803',
#     'versieId': '2013-03-29T09:43:54+01:00'},
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/adressen/4334803',
#    'gemeente': {'objectId': '11002',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/gemeenten/11002',
#     'gemeentenaam': {'geografischeNaam': {'spelling': 'Antwerpen',
#       'taal': 'nl'}}},
#    'postinfo': {'objectId': '2000',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/postinfo/2000'},
#    'straatnaam': {'objectId': '2655',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/straatnamen/2655',
#     'straatnaam': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet',
#       'taal': 'nl'}}},
#    'huisnummer': '7',
#    'busnummer': '4',
#    'volledigAdres': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet 7 bus 4, 2000 Antwerpen',
#      'taal': 'nl'}},
#    'adresPositie': {'point': {'coordinates': [152242.43, 212849.5],
#      'type': 'Point'}},
#    'positieSpecificatie': 'gebouweenheid',
#    'positieGeometrieMethode': 'afgeleidVanObject',
#    'adresStatus': 'inGebruik',
#    'officieelToegekend': True,
#    'adresseerbareObjecten': [{'objectType': 'gebouweenheid',
#      'objectId': '16689269',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/16689269'},
#     {'objectType': 'perceel',
#      'objectId': '11002A1949-03A000',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/percelen/11002A1949-03A000'}],
#    'score': 91.10245022508234},
#   {'identificator': {'id': 'https://data.vlaanderen.be/id/adres/4392078',
#     'naamruimte': 'https://data.vlaanderen.be/id/adres',
#     'objectId': '4392078',
#     'versieId': '2013-03-29T10:02:23+01:00'},
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/adressen/4392078',
#    'gemeente': {'objectId': '11002',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/gemeenten/11002',
#     'gemeentenaam': {'geografischeNaam': {'spelling': 'Antwerpen',
#       'taal': 'nl'}}},
#    'postinfo': {'objectId': '2000',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/postinfo/2000'},
#    'straatnaam': {'objectId': '2655',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/straatnamen/2655',
#     'straatnaam': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet',
#       'taal': 'nl'}}},
#    'huisnummer': '7',
#    'busnummer': '7',
#    'volledigAdres': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet 7 bus 7, 2000 Antwerpen',
#      'taal': 'nl'}},
#    'adresPositie': {'point': {'coordinates': [152242.43, 212849.5],
#      'type': 'Point'}},
#    'positieSpecificatie': 'gebouweenheid',
#    'positieGeometrieMethode': 'afgeleidVanObject',
#    'adresStatus': 'inGebruik',
#    'officieelToegekend': True,
#    'adresseerbareObjecten': [{'objectType': 'gebouweenheid',
#      'objectId': '16689267',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/16689267'},
#     {'objectType': 'perceel',
#      'objectId': '11002A1949-03A000',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/percelen/11002A1949-03A000'}],
#    'score': 91.10245022508234},
#   {'identificator': {'id': 'https://data.vlaanderen.be/id/adres/4311781',
#     'naamruimte': 'https://data.vlaanderen.be/id/adres',
#     'objectId': '4311781',
#     'versieId': '2013-03-29T10:02:39+01:00'},
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/adressen/4311781',
#    'gemeente': {'objectId': '11002',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/gemeenten/11002',
#     'gemeentenaam': {'geografischeNaam': {'spelling': 'Antwerpen',
#       'taal': 'nl'}}},
#    'postinfo': {'objectId': '2000',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/postinfo/2000'},
#    'straatnaam': {'objectId': '2655',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/straatnamen/2655',
#     'straatnaam': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet',
#       'taal': 'nl'}}},
#    'huisnummer': '7',
#    'busnummer': '8',
#    'volledigAdres': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet 7 bus 8, 2000 Antwerpen',
#      'taal': 'nl'}},
#    'adresPositie': {'point': {'coordinates': [152242.43, 212849.5],
#      'type': 'Point'}},
#    'positieSpecificatie': 'gebouweenheid',
#    'positieGeometrieMethode': 'afgeleidVanObject',
#    'adresStatus': 'inGebruik',
#    'officieelToegekend': True,
#    'adresseerbareObjecten': [{'objectType': 'gebouweenheid',
#      'objectId': '16689268',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/16689268'},
#     {'objectType': 'perceel',
#      'objectId': '11002A1949-03A000',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/percelen/11002A1949-03A000'}],
#    'score': 91.10245022508234},
#   {'identificator': {'id': 'https://data.vlaanderen.be/id/adres/4402686',
#     'naamruimte': 'https://data.vlaanderen.be/id/adres',
#     'objectId': '4402686',
#     'versieId': '2013-03-29T10:53:48+01:00'},
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/adressen/4402686',
#    'gemeente': {'objectId': '11002',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/gemeenten/11002',
#     'gemeentenaam': {'geografischeNaam': {'spelling': 'Antwerpen',
#       'taal': 'nl'}}},
#    'postinfo': {'objectId': '2000',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/postinfo/2000'},
#    'straatnaam': {'objectId': '2655',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/straatnamen/2655',
#     'straatnaam': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet',
#       'taal': 'nl'}}},
#    'huisnummer': '7',
#    'busnummer': '9',
#    'volledigAdres': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet 7 bus 9, 2000 Antwerpen',
#      'taal': 'nl'}},
#    'adresPositie': {'point': {'coordinates': [152242.43, 212849.5],
#      'type': 'Point'}},
#    'positieSpecificatie': 'gebouweenheid',
#    'positieGeometrieMethode': 'afgeleidVanObject',
#    'adresStatus': 'inGebruik',
#    'officieelToegekend': True,
#    'adresseerbareObjecten': [{'objectType': 'gebouweenheid',
#      'objectId': '16689266',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/16689266'},
#     {'objectType': 'perceel',
#      'objectId': '11002A1949-03A000',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/percelen/11002A1949-03A000'}],
#    'score': 91.10245022508234},
#   {'identificator': {'id': 'https://data.vlaanderen.be/id/adres/4833661',
#     'naamruimte': 'https://data.vlaanderen.be/id/adres',
#     'objectId': '4833661',
#     'versieId': '2013-03-29T10:43:43+01:00'},
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/adressen/4833661',
#    'gemeente': {'objectId': '11002',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/gemeenten/11002',
#     'gemeentenaam': {'geografischeNaam': {'spelling': 'Antwerpen',
#       'taal': 'nl'}}},
#    'postinfo': {'objectId': '2000',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/postinfo/2000'},
#    'straatnaam': {'objectId': '2655',
#     'detail': 'https://api.basisregisters.vlaanderen.be/v1/straatnamen/2655',
#     'straatnaam': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet',
#       'taal': 'nl'}}},
#    'huisnummer': '7',
#    'busnummer': '11',
#    'volledigAdres': {'geografischeNaam': {'spelling': 'Sint-Pietersvliet 7 bus 11, 2000 Antwerpen',
#      'taal': 'nl'}},
#    'adresPositie': {'point': {'coordinates': [152242.43, 212849.5],
#      'type': 'Point'}},
#    'positieSpecificatie': 'gebouweenheid',
#    'positieGeometrieMethode': 'afgeleidVanObject',
#    'adresStatus': 'inGebruik',
#    'officieelToegekend': True,
#    'adresseerbareObjecten': [{'objectType': 'gebouweenheid',
#      'objectId': '16689265',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/16689265'},
#     {'objectType': 'perceel',
#      'objectId': '11002A1949-03A000',
#      'detail': 'https://api.basisregisters.vlaanderen.be/v1/percelen/11002A1949-03A000'}],
#    'score': 91.10245022508234}],
#  'warnings': []}

# %%
import requests
import earthpy.plot as ep
import json

#responsetest = response3['adresMatches']['identificator']['adresseerbareObjecten']['detail'][0]
response2 = requests.get(response1['adresMatches'][0]['adresseerbareObjecten'][0]['detail']).json()

response = requests.get("https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570703").json()

responsetest
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second api trial-checkpoint.ipynb Cell 3' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000002?line=2'>3</a> import json
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000002?line=4'>5</a> #responsetest = response3['adresMatches']['identificator']['adresseerbareObjecten']['detail'][0]
# ----> <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000002?line=5'>6</a> responsetest = response3['adresseerbareObjecten'][0]['objectType']['detail']
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000002?line=7'>8</a> response = requests.get("https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570703").json()
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000002?line=9'>10</a> responsetest
#
# KeyError: 'adresseerbareObjecten'

# %%
import requests
import earthpy.plot as ep
import json
from shapely.geometry.polygon import Polygon
import rasterio
from glob import glob


streetname = input('Give me the streetname?')
housenumber = input('Give me the housenumber?')
zipcode = input('Give me the zipcode?')
adres_api = {"straatnaam":{streetname}, "huisnummer":{housenumber}, "postcode":{zipcode}}
api_url = "https://api.basisregisters.vlaanderen.be/v1/adresmatch"
response1 = requests.get(url = api_url, params = adres_api).json()
response1

response2 = requests.get(response1['adresMatches'][0]['adresseerbareObjecten'][0]['detail']).json()

response3 = requests.get(response2['gebouw']['detail']).json()

polygon_house = Polygon(response3["geometriePolygoon"]["polygon"]["coordinates"][0])
type(polygon_house)
float_house = (response3["geometriePolygoon"]["polygon"]["coordinates"][0])
polygon_house

# %%
dsm14 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDSMRAS1m_k14.tif"
dtm14 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDTMRAS1m_k14.tif"
dsm22 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDSMRAS1m_k22.tif"
dtm22 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDTMRAS1m_k22.tif"
dsm15 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDSMRAS1m_k15.tif"
dtm15 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDTMRAS1m_k15.tif"
dsm23 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDSMRAS1m_k23.tif"
dtm23 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDTMRAS1m_k23.tif"
dsm30 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDSMRAS1m_k30.tif"
dtm30 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k/GeoTIFFall/DHMVIIDTMRAS1m_k30.tif"

# %%
import requests
import earthpy.plot as ep
import json
response4 = requests.get("https://api.basisregisters.vlaanderen.be/v1/gebouwen/7569832").json()
response4
# Out:
# {'identificator': {'id': 'https://data.vlaanderen.be/id/gebouw/7569832',
#   'naamruimte': 'https://data.vlaanderen.be/id/gebouw',
#   'objectId': '7569832',
#   'versieId': '2017-03-09T17:15:54+01:00'},
#  'geometriePolygoon': {'polygon': {'coordinates': [[[121465.63794352859,
#       199545.93402853236],
#      [121465.37227953225, 199545.9234685339],
#      [121459.25586352497, 199545.67969253287],
#      [121459.23755952716, 199546.13934053108],
#      [121453.00024752319, 199545.89204453304],
#      [121452.9961515218, 199545.9920125343],
#      [121451.19967152178, 199545.91854053363],
#      [121451.20376752317, 199545.8185725324],
#      [121444.96619951725, 199545.56090853363],
#      [121445.48895151913, 199532.90887652338],
#      [121458.08927152306, 199533.4747645259],
#      [121466.20171952993, 199534.0245245248],
#      [121466.00920753181, 199538.2773245275],
#      [121466.10911153257, 199538.28103652596],
#      [121466.04319152981, 199540.06343653053],
#      [121465.94322352856, 199540.05972452834],
#      [121465.63794352859, 199545.93402853236]]],
#    'type': 'Polygon'}},
#  'geometrieMethode': 'ingemetenGRB',
#  'gebouwStatus': 'gerealiseerd',
#  'gebouweenheden': [{'objectId': '7570694',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570694'},
#   {'objectId': '7570695',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570695'},
#   {'objectId': '7570696',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570696'},
#   {'objectId': '7570697',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570697'},
#   {'objectId': '7570698',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570698'},
#   {'objectId': '7570699',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570699'},
#   {'objectId': '7570700',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570700'},
#   {'objectId': '7570701',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570701'},
#   {'objectId': '7570702',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570702'},
#   {'objectId': '7570703',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/7570703'},
#   {'objectId': '30316087',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/30316087'},
#   {'objectId': '30316088',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/gebouweenheden/30316088'}],
#  'percelen': [{'objectId': '46383D1389-00L000',
#    'detail': 'https://api.basisregisters.vlaanderen.be/v1/percelen/46383D1389-00L000'}]}

# %%
import requests
import earthpy.plot as ep
import json
from shapely.geometry.polygon import Polygon

response4 = requests.get("https://api.basisregisters.vlaanderen.be/v1/gebouwen/7569832").json()
polygon_house = Polygon(response4["geometriePolygoon"]["polygon"]["coordinates"][0])
type(polygon_house)
#save polygon_house as a shapefile and then try to 3d plot it
float_house = (response4["geometriePolygoon"]["polygon"]["coordinates"][0])

# %%
import geopandas as gpd
dsm14 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k14/GeoTIFF/DHMVIIDSMRAS1m_k14.tif"
dtm14 = "/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/GeoTIFF/DHMVIIDTMRAS1m_k14.tif"
shpfile14 = gpd.read_file("/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/DHMVII_vdc_k14/DHMVII_vdc_k14.shp")
dsm22 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k22/GeoTIFF/DHMVIIDSMRAS1m_k22.tif""/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/DHMVII_vdc_k14/DHMVII_vdc_k14.shp"
dtm22 = "/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k22/GeoTIFF/DHMVIIDTMRAS1m_k22.tif"
shpfile22 = gpd.read_file("/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k22/DHMVII_vdc_k22/DHMVII_vdc_k22.shp")
dsm15 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k15/GeoTIFF/DHMVIIDSMRAS1m_k15.tif"
dtm15 = "/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k15/GeoTIFF/DHMVIIDTMRAS1m_k15.tif"
shpfile15 = gpd.read_file("/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k15/DHMVII_vdc_k15/DHMVII_vdc_k15.shp")
dsm23 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k23/GeoTIFF/DHMVIIDSMRAS1m_k23.tif"
dtm23 = "/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k23/GeoTIFF/DHMVIIDTMRAS1m_k23.tif"
shpfile23 = gpd.read_file("/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k23/DHMVII_vdc_k23/DHMVII_vdc_k23.shp")
dsm30 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k30/GeoTIFF/DHMVIIDSMRAS1m_k30.tif"
dtm30 = "/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k30/GeoTIFF/DHMVIIDTMRAS1m_k30.tif"
shpfile30 = gpd.read_file("/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k30/DHMVII_vdc_k30/DHMVII_vdc_k30.shp")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/DHMVII_vdc_k14/DHMVII_vdc_k14.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# /Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second api trial-checkpoint.ipynb Cell 6' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000004?line=1'>2</a> dsm14 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k14/GeoTIFF/DHMVIIDSMRAS1m_k14.tif"
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000004?line=2'>3</a> dtm14 = "/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/GeoTIFF/DHMVIIDTMRAS1m_k14.tif"
# ----> <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000004?line=3'>4</a> shpfile14 = gpd.read_file("/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/DHMVII_vdc_k14/DHMVII_vdc_k14.shp")
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000004?line=4'>5</a> dsm22 = "/Users/Jorg/3D_houses_data/DHMVIIDSMRAS1m_k22/GeoTIFF/DHMVIIDSMRAS1m_k22.tif""/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/DHMVII_vdc_k14/DHMVII_vdc_k14.shp"
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000004?line=5'>6</a> dtm22 = "/Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k22/GeoTIFF/DHMVIIDTMRAS1m_k22.tif"
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/io/file.py:201, in _read_file(filename, bbox, mask, rows, **kwargs)
#     198     reader = fiona.open
#     200 with fiona_env():
# --> 201     with reader(path_or_bytes, **kwargs) as features:
#     202
#     203         # In a future Fiona release the crs attribute of features will
#     204         # no longer be a dict, but will behave like a dict. So this should
#     205         # be forwards compatible
#     206         crs = (
#     207             features.crs["init"]
#     208             if features.crs and "init" in features.crs
#     209             else features.crs_wkt
#     210         )
#     212         # handle loading the bounding box
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/fiona/env.py:408, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwargs)
#     405 @wraps(f)
#     406 def wrapper(*args, **kwargs):
#     407     if local._env:
# --> 408         return f(*args, **kwargs)
#     409     else:
#     410         if isinstance(args[0], str):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/fiona/__init__.py:264, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     261     path = parse_path(fp)
#     263 if mode in ('a', 'r'):
# --> 264     c = Collection(path, mode, driver=driver, encoding=encoding,
#     265                    layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     266 elif mode == 'w':
#     267     if schema:
#     268         # Make an ordered dict of schema properties.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/fiona/collection.py:162, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160 if self.mode == 'r':
#     161     self.session = Session()
# --> 162     self.session.start(self, **kwargs)
#     163 elif self.mode in ('a', 'w'):
#     164     self.session = WritingSession()
#
# File fiona/ogrext.pyx:540, in fiona.ogrext.Session.start()
#
# File fiona/_shim.pyx:90, in fiona._shim.gdal_open_vector()
#
# DriverError: /Users/Jorg/3D_houses_data/DHMVIIDTMRAS1m_k14/DHMVII_vdc_k14/DHMVII_vdc_k14.shp: No such file or directory

# %%
import rasterio
import requests
import json
from shapely.geometry.polygon import Polygon

src = rasterio.open(dsm15)
src.bounds


for x, y in float_house:
    if src.bounds[0] < x < src.bounds[2] and src.bounds[1] < y < src.bounds[3]:
        print("inside")
    else:
        print("outside")
# Out:
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside

# %%
import rioxarray
import fiona
import rasterio
import rasterio.mask
from PIL import Image


with rasterio.open(dsm15) as src:
    out_image, out_transform = rasterio.mask.mask(src, [polygon_house], crop=True)
    clipdsm = out_image[0]
    
with rasterio.open(dtm15) as src:
    out_image, out_transform = rasterio.mask.mask(src, [polygon_house], crop=True)
    clipdtm = out_image[0]

clipchm = clipdsm - clipdtm

# %%
chm
# Out:
# <xarray.DataArray (band: 1, y: 73, x: 54)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])
# Coordinates:
#   * x            (x) float64 1.522e+05 1.522e+05 ... 1.523e+05 1.523e+05
#   * y            (y) float64 2.129e+05 2.129e+05 ... 2.128e+05 2.128e+05
#   * band         (band) int64 1
#     spatial_ref  int64 0

# %%
import plotly.graph_objects as go
from PIL import Image
import imageio
import pandas as pd
import matplotlib.pyplot as plt

image_chm = imageio.imread(r'clipped_invert.tif')
fig = go.Figure(data=[go.Surface(z=clipchm)])

fig.update_layout(title='CHM', autosize=False,
                  width=600, height=600)

fig.show()

# %%
src = rasterio.open(dsm15)
src.bounds

for x, y in float_house:
    if src.bounds[0] < x < src.bounds[2] and src.bounds[1] < y < src.bounds[3]:
        print("inside")
    else:
        print("outside")

glob('*.tif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second api trial-checkpoint.ipynb Cell 14' in <cell line: 23>()
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=6'>7</a> #with rio.open(chm) as src:
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=7'>8</a> #    elevation = src.read(1)
#       <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=8'>9</a> #poly_chm = Polygon(chm(zip(x, y)))
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=10'>11</a> bamako= [[0.0, 'rgb(0, 63, 76)'], # a scientific colorscale for dem data
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=11'>12</a>  [0.1, 'rgb(29, 81, 59)'],
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=12'>13</a>  [0.2, 'rgb(55, 98, 43)'],
#    (...)
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=19'>20</a>  [0.9, 'rgb(234, 209, 112)'],
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=20'>21</a>  [1.0, 'rgb(254, 229, 152)']]
# ---> <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=22'>23</a> fig= px.imshow(chm, color_continuous_scale=bamako)
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=23'>24</a> my_layout= dict(title_text='Big Tujunga Cachement-California', title_x=0.5, width =700, height=500, template='none',
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=24'>25</a>                   coloraxis_colorbar=dict(len=0.75, thickness=25))
#      <a href='vscode-notebook-cell:/Users/Jorg/BeCode/3D_houses/.ipynb_checkpoints/second%20api%20trial-checkpoint.ipynb#ch0000011?line=25'>26</a> fig.update_layout(**my_layout)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_imshow.py:530, in imshow(img, zmin, zmax, origin, labels, x, y, animation_frame, facet_col, facet_col_wrap, facet_col_spacing, facet_row_spacing, color_continuous_scale, color_continuous_midpoint, range_color, title, template, width, height, aspect, contrast_rescaling, binary_string, binary_backend, binary_compression_level, binary_format, text_auto)
#     528         layout["xaxis"] = dict(autorange="reversed")
#     529 else:
# --> 530     raise ValueError(
#     531         "px.imshow only accepts 2D single-channel, RGB or RGBA images. "
#     532         "An image of shape %s was provided. "
#     533         "Alternatively, 3- or 4-D single or multichannel datasets can be "
#     534         "visualized using the `facet_col` or/and `animation_frame` arguments."
#     535         % str(img.shape)
#     536     )
#     538 # Now build figure
#     539 col_labels = []
#
# ValueError: px.imshow only accepts 2D single-channel, RGB or RGBA images. An image of shape (1, 73, 54) was provided. Alternatively, 3- or 4-D single or multichannel datasets can be visualized using the `facet_col` or/and `animation_frame` arguments.
